# %%
import pandas as pd

# %%
df = pd.read_csv('pokemon_data.csv',delimiter=',')

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
df.describe()
# Out:
#                 #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.000000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750   69.258750   79.001250   73.842500   72.820000   71.902500
# std    208.343798   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.000000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    184.750000   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    364.500000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    539.250000   80.000000  100.000000   90.000000   95.000000   90.000000
# max    721.000000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# ...

# %%
# To Get the records and their counts
df['Legendary'].value_counts()
# Out:
# False    735
# True      65
# Name: Legendary, dtype: int64

# %%
# To know about the columns
df.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
# To get row 1 to 4
df.iloc[1:5]
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
# Try to get the value of "Charmander" name here
df.iloc[4,1]
# Out:
# 'Charmander'

# %%
# To iter through the rows
for index,rows in df.iterrows():
    print(index,rows['Type 1'])
# Out:
# 0 Grass
# 1 Grass
# 2 Grass
# 3 Grass
# 4 Fire
# 5 Fire
# 6 Fire
# 7 Fire
# 8 Fire
# 9 Water
# 10 Water
# 11 Water
# 12 Water
# 13 Bug
# 14 Bug
# 15 Bug
# 16 Bug
# 17 Bug
# 18 Bug
# 19 Bug
# 20 Normal
# 21 Normal
# 22 Normal
# 23 Normal
# 24 Normal
# 25 Normal
# 26 Normal
# 27 Normal
# 28 Poison
# 29 Poison
# 30 Electric
# 31 Electric
# 32 Ground
# 33 Ground
# 34 Poison
# 35 Poison
# 36 Poison
# 37 Poison
# 38 Poison
# 39 Poison
# 40 Fairy
# 41 Fairy
# 42 Fire
# 43 Fire
# 44 Normal
# 45 Normal
# 46 Poison
# 47 Poison
# 48 Grass
# 49 Grass
# 50 Grass
# 51 Bug
# 52 Bug
# 53 Bug
# 54 Bug
# 55 Ground
# 56 Ground
# 57 Normal
# 58 Normal
# 59 Water
# 60 Water
# 61 Fighting
# 62 Fighting
# 63 Fire
# 64 Fire
# 65 Water
# 66 Water
# 67 Water
# 68 Psychic
# 69 Psychic
# 70 Psychic
# 71 Psychic
# 72 Fighting
# 73 Fighting
# 74 Fighting
# 75 Grass
# 76 Grass
# 77 Grass
# 78 Water
# 79 Water
# 80 Rock
# 81 Rock
# 82 Rock
# 83 Fire
# 84 Fire
# 85 Water
# 86 Water
# 87 Water
# 88 Electric
# ...

# %%
# To fetch the records with Type 1 = 'Grass'
df.loc[df['Type 1']=='Grass']
# Out:
#        #                   Name Type 1    Type 2   HP  Attack  Defense  \
# 0      1              Bulbasaur  Grass    Poison   45      49       49
# 1      2                Ivysaur  Grass    Poison   60      62       63
# 2      3               Venusaur  Grass    Poison   80      82       83
# 3      3  VenusaurMega Venusaur  Grass    Poison   80     100      123
# 48    43                 Oddish  Grass    Poison   45      50       55
# ..   ...                    ...    ...       ...  ...     ...      ...
# 718  650                Chespin  Grass       NaN   56      61       65
# 719  651              Quilladin  Grass       NaN   61      78       95
# 720  652             Chesnaught  Grass  Fighting   88     107      122
# 740  672                 Skiddo  Grass       NaN   66      65       48
# 741  673                 Gogoat  Grass       NaN  123     100       62
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
# Sorting values by a specific column
df.sort_values(by="Name",ascending=False)
# Out:
#        #                     Name   Type 1  Type 2   HP  Attack  Defense  \
# 794  718         Zygarde50% Forme   Dragon  Ground  108     100      121
# 695  634                 Zweilous     Dark  Dragon   72      85       70
# 46    41                    Zubat   Poison  Flying   40      45       35
# 631  570                    Zorua     Dark     NaN   40      65       40
# 632  571                  Zoroark     Dark     NaN   60     105       60
# ..   ...                      ...      ...     ...  ...     ...      ...
# 393  359          AbsolMega Absol     Dark     NaN   65     150       60
# 392  359                    Absol     Dark     NaN   65     130       60
# 68    63                     Abra  Psychic     NaN   25      20       15
# 511  460  AbomasnowMega Abomasnow    Grass     Ice   90     132      105
# 510  460                Abomasnow    Grass     Ice   90      92       75
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
# Sorting the values by two columns
df.sort_values(by=['Name','Type 1'],ascending=False)
# Out:
#        #                     Name   Type 1  Type 2   HP  Attack  Defense  \
# 794  718         Zygarde50% Forme   Dragon  Ground  108     100      121
# 695  634                 Zweilous     Dark  Dragon   72      85       70
# 46    41                    Zubat   Poison  Flying   40      45       35
# 631  570                    Zorua     Dark     NaN   40      65       40
# 632  571                  Zoroark     Dark     NaN   60     105       60
# ..   ...                      ...      ...     ...  ...     ...      ...
# 393  359          AbsolMega Absol     Dark     NaN   65     150       60
# 392  359                    Absol     Dark     NaN   65     130       60
# 68    63                     Abra  Psychic     NaN   25      20       15
# 511  460  AbomasnowMega Abomasnow    Grass     Ice   90     132      105
# 510  460                Abomasnow    Grass     Ice   90      92       75
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
# First ascending and then descinding
df.sort_values(by=['Name','Type 1'],ascending=[1,0])
# Out:
#        #                     Name   Type 1  Type 2   HP  Attack  Defense  \
# 510  460                Abomasnow    Grass     Ice   90      92       75
# 511  460  AbomasnowMega Abomasnow    Grass     Ice   90     132      105
# 68    63                     Abra  Psychic     NaN   25      20       15
# 392  359                    Absol     Dark     NaN   65     130       60
# 393  359          AbsolMega Absol     Dark     NaN   65     150       60
# ..   ...                      ...      ...     ...  ...     ...      ...
# 632  571                  Zoroark     Dark     NaN   60     105       60
# 631  570                    Zorua     Dark     NaN   40      65       40
# 46    41                    Zubat   Poison  Flying   40      45       35
# 695  634                 Zweilous     Dark  Dragon   72      85       70
# 794  718         Zygarde50% Forme   Dragon  Ground  108     100      121
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
# Adding the numeric values
df['Total'] = df['HP'] + df['Attack'] + df['Defense'] + df['Sp. Atk'] + df['Sp. Def'] + df['Speed']

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  Total
# 0       65     45           1      False    318
# 1       80     60           1      False    405
# 2      100     80           1      False    525
# 3      120     80           1      False    625
# 4       50     65           1      False    309

# %%
# To drop a specific column in the dataFrame
df.drop(['Total','Generation'],axis=1)
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Legendary
# 0         65       65     45      False
# 1         80       80     60      False
# ...

# %%
df = df.drop(['Total'],axis=1)

# %%
# To add the column [rows:rows,columns:columns]
df['Total'] = df.iloc[:,4:10].sum(axis=1)

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  Total
# 0       65     45           1      False    318
# 1       80     60           1      False    405
# 2      100     80           1      False    525
# 3      120     80           1      False    625
# 4       50     65           1      False    309

# %%
df.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary', 'Total'],
#       dtype='object')

# %%
df = df[['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
       'Sp. Def', 'Speed', 'Total','Generation', 'Legendary', ]]

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Total  Generation  Legendary
# 0       65     45    318           1      False
# 1       80     60    405           1      False
# 2      100     80    525           1      False
# 3      120     80    625           1      False
# 4       50     65    309           1      False

# %%
# To save the file
df.to_csv('pokemon_modified.csv',index=False)

# %%
## To filter the data
new_df = df[(df['Type 1'] == 'Grass') & (df['Type 2']=='Poison')]

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15 entries, 0 to 652
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           15 non-null     int64
#  1   Name        15 non-null     object
#  2   Type 1      15 non-null     object
#  3   Type 2      15 non-null     object
#  4   HP          15 non-null     int64
#  5   Attack      15 non-null     int64
#  6   Defense     15 non-null     int64
#  7   Sp. Atk     15 non-null     int64
#  8   Sp. Def     15 non-null     int64
#  9   Speed       15 non-null     int64
#  10  Total       15 non-null     int64
#  11  Generation  15 non-null     int64
#  12  Legendary   15 non-null     bool
# dtypes: bool(1), int64(9), object(3)
# memory usage: 1.5+ KB

# %%
############################

# %% [markdown]
# ## Filter the data with matching patterns

# %%
df[df['Name'].str.contains('Mega')].head(5)
# Out:
#        #                 Name Type 1 Type 2  HP  Attack  Defense  Sp. Atk  \
# 796  719  DiancieMega Diancie   Rock  Fairy  50     160      110      160
#
#      Sp. Def  Speed  Total  Generation  Legendary
# 796      110    110    700           6       True

# %%
df[df['Type 1'].str.contains('Fire|Grass', regex=True)].head(5)
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Total  Generation  Legendary
# 0       65     45    318           1      False
# 1       80     60    405           1      False
# 2      100     80    525           1      False
# 3      120     80    625           1      False
# 4       50     65    309           1      False

# %%
# With case incensitive
import re
df[df['Type 1'].str.contains('fiRe|grAsS',flags=re.I, regex=True)]
# Out:
#        #                   Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 0      1              Bulbasaur  Grass  Poison   45      49       49       65
# 1      2                Ivysaur  Grass  Poison   60      62       63       80
# 2      3               Venusaur  Grass  Poison   80      82       83      100
# 3      3  VenusaurMega Venusaur  Grass  Poison   80     100      123      122
# 4      4             Charmander   Fire     NaN   39      52       43       60
# ..   ...                    ...    ...     ...  ...     ...      ...      ...
# 735  667                 Litleo   Fire  Normal   62      50       58       73
# 736  668                 Pyroar   Fire  Normal   86      68       72      109
# 740  672                 Skiddo  Grass     NaN   66      65       48       62
# 741  673                 Gogoat  Grass     NaN  123     100       62       97
# 799  721              Volcanion   Fire   Water   80     110      120      130
#
# ...

# %%
df[df['Name'].str.contains('pi[a-z]',flags=re.I, regex=True)]
# Out:
#        #                     Name    Type 1    Type 2   HP  Attack  Defense  \
# 13    10                 Caterpie       Bug       NaN   45      30       35
# 20    16                   Pidgey    Normal    Flying   40      45       40
# 21    17                Pidgeotto    Normal    Flying   63      60       55
# 22    18                  Pidgeot    Normal    Flying   83      80       75
# 23    18      PidgeotMega Pidgeot    Normal    Flying   83      80       80
# 30    25                  Pikachu  Electric       NaN   35      55       40
# 42    37                   Vulpix      Fire       NaN   38      41       40
# 76    70               Weepinbell     Grass    Poison   65      90       50
# 84    78                 Rapidash      Fire       NaN   65     100       70
# 136  127                   Pinsir       Bug       NaN   65     125      100
# 137  127        PinsirMega Pinsir       Bug    Flying   65     155      120
# ...

# %% [markdown]
# ## Using Regex in python Pandas

# %%
df[df['Name'].str.contains('^pi[a-z]',flags=re.I, regex=True)]
# Out:
#        #                 Name    Type 1    Type 2   HP  Attack  Defense  \
# 20    16               Pidgey    Normal    Flying   40      45       40
# 21    17            Pidgeotto    Normal    Flying   63      60       55
# 22    18              Pidgeot    Normal    Flying   83      80       75
# 23    18  PidgeotMega Pidgeot    Normal    Flying   83      80       80
# 30    25              Pikachu  Electric       NaN   35      55       40
# 136  127               Pinsir       Bug       NaN   65     125      100
# 137  127    PinsirMega Pinsir       Bug    Flying   65     155      120
# 186  172                Pichu  Electric       NaN   20      40       15
# 219  204               Pineco       Bug       NaN   50      65       90
# 239  221            Piloswine       Ice    Ground  100     100       80
# 438  393               Piplup     Water       NaN   53      51       53
# 558  499              Pignite      Fire  Fighting   90      93       55
# ...

# %% [markdown]
# ## Derive a conditional column for your data

# %%
df.loc[df['Type 1']=='Fire', 'Legendary'] =True

# %%
df.head(5)
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Total  Generation  Legendary
# 0       65     45    318           1      False
# 1       80     60    405           1      False
# 2      100     80    525           1      False
# 3      120     80    625           1      False
# 4       50     65    309           1       True

# %%
df.loc[df['Type 2']=='Poison', 'Legendary'] = 'Type2 is Poison'
df.head(5)
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Total  Generation        Legendary
# 0       65     45    318           1  Type2 is Poison
# 1       80     60    405           1  Type2 is Poison
# 2      100     80    525           1  Type2 is Poison
# 3      120     80    625           1  Type2 is Poison
# 4       50     65    309           1             True

# %%
###############################

# %%
########### Group by ##########

# %%
df = pd.read_csv('pokemon_modified.csv')

# %% [markdown]
# ## Getting top 10 Pokemon Total

# %%
df.groupby('Name').sum()['Total'].sort_values(ascending=False)[1:10]
# Out:
# Name
# MewtwoMega Mewtwo X        780
# RayquazaMega Rayquaza      780
# KyogrePrimal Kyogre        770
# GroudonPrimal Groudon      770
# Arceus                     720
# LatiasMega Latias          700
# TyranitarMega Tyranitar    700
# DiancieMega Diancie        700
# KyuremBlack Kyurem         700
# Name: Total, dtype: int64

# %%
df.groupby('Type 1').mean()['Total'].sort_values(ascending=False)[1:10]
# Out:
# Type 1
# Steel       487.703704
# Flying      485.000000
# Psychic     475.947368
# Fire        458.076923
# Rock        453.750000
# Dark        445.741935
# Electric    443.409091
# Ghost       439.562500
# Ground      437.500000
# Name: Total, dtype: float64

# %%
# Group by two columns
df.groupby(['Type 1','Type 2']).mean()['Total'].sort_values(ascending=False)[1:10]
# Out:
# Type 1   Type 2
# Dragon   Ice         686.666667
# Steel    Dragon      680.000000
# Ghost    Dragon      680.000000
# Psychic  Dark        680.000000
# Dragon   Fire        680.000000
#          Electric    680.000000
# Rock     Dark        650.000000
# Dragon   Psychic     650.000000
#          Flying      641.666667
# Name: Total, dtype: float64

# %%
##############################

# %%
######## Working with Large files

# %%
for df in pd.read_csv('pokemon_modified.csv',chunksize=10):
    print(df)
# Out:
#    #                       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1                  Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                    Ivysaur  Grass  Poison  60      62       63       80
# 2  3                   Venusaur  Grass  Poison  80      82       83      100
# 3  3      VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4                 Charmander   Fire     NaN  39      52       43       60
# 5  5                 Charmeleon   Fire     NaN  58      64       58       80
# 6  6                  Charizard   Fire  Flying  78      84       78      109
# 7  6  CharizardMega Charizard X   Fire  Dragon  78     130      111      130
# 8  6  CharizardMega Charizard Y   Fire  Flying  78     104       78      159
# 9  7                   Squirtle  Water     NaN  44      48       65       50
#
#    Sp. Def  Speed  Total  Generation  Legendary
# 0       65     45    318           1      False
# ...

# %% [markdown]
# ### To check the version of Pandas

# %%
pd.show_versions()
# Out:
# INSTALLED VERSIONS
# ------------------
# commit           : 945c9ed766a61c7d2c0a7cbb251b6edebf9cb7d5
# python           : 3.7.11.final.0
# python-bits      : 64
# OS               : Windows
# OS-release       : 10
# Version          : 10.0.19041
# machine          : AMD64
# processor        : Intel64 Family 6 Model 158 Stepping 10, GenuineIntel
# byteorder        : little
# LC_ALL           : None
# LANG             : None
# LOCALE           : None.None
#
# pandas           : 1.3.4
# numpy            : 1.21.4
# pytz             : 2021.3
# dateutil         : 2.8.2
# pip              : 21.3.1
# setuptools       : 58.0.4
# Cython           : 0.29.23
# pytest           : None
# hypothesis       : None
# sphinx           : None
# blosc            : None
# feather          : None
# xlsxwriter       : None
# lxml.etree       : 4.7.1
# html5lib         : None
# pymysql          : None
# psycopg2         : None
# jinja2           : None
# IPython          : 7.30.0
# pandas_datareader: None
# ...

# %%
df.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Total', 'Generation', 'Legendary'],
#       dtype='object')

# %%
# To rename a column in pandas
df.rename({'Type 1':'Type1','Type 2':'Type2','#':'SrNo'},axis='columns')
# Out:
#      SrNo                 Name    Type1   Type2   HP  Attack  Defense  \
# 790   714               Noibat   Flying  Dragon   40      30       35
# 791   715              Noivern   Flying  Dragon   85      70       80
# 792   716              Xerneas    Fairy     NaN  126     131       95
# 793   717              Yveltal     Dark  Flying  126     131       95
# 794   718     Zygarde50% Forme   Dragon  Ground  108     100      121
# 795   719              Diancie     Rock   Fairy   50     100      150
# 796   719  DiancieMega Diancie     Rock   Fairy   50     160      110
# 797   720  HoopaHoopa Confined  Psychic   Ghost   80     110       60
# 798   720   HoopaHoopa Unbound  Psychic    Dark   80     160       60
# 799   721            Volcanion     Fire   Water   80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Total  Generation  Legendary
# 790       45       40     55    245           6      False
# 791       97       80    123    535           6      False
# ...

# %% [markdown]
# ## TO check the data types of columns

# %%
df.dtypes
# Out:
# #              int64
# Name          object
# Type 1        object
# Type 2        object
# HP             int64
# Attack         int64
# Defense        int64
# Sp. Atk        int64
# Sp. Def        int64
# Speed          int64
# Total          int64
# Generation     int64
# Legendary       bool
# dtype: object

# %% [markdown]
# ## Select columns based on specific data types

# %%
df.select_dtypes(include=['int64','bool'])
# Out:
#        #   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  Total  Generation  \
# 790  714   40      30       35       45       40     55    245           6
# 791  715   85      70       80       97       80    123    535           6
# 792  716  126     131       95      131       98     99    680           6
# 793  717  126     131       95      131       98     99    680           6
# 794  718  108     100      121       81       95     95    600           6
# 795  719   50     100      150      100      150     50    600           6
# 796  719   50     160      110      160      110    110    700           6
# 797  720   80     110       60      150      130     70    600           6
# 798  720   80     160       60      170      130     80    680           6
# 799  721   80     110      120      130       90     70    600           6
#
#      Legendary
# 790      False
# 791      False
# 792       True
# 793       True
# 794       True
# 795       True
# 796       True
# ...

# %% [markdown]
# ## Reduce dataFrame size

# %%
pd.read_csv('pokemon_data.csv',usecols=['Attack','Defense','Legendary'])
# Out:
#      Attack  Defense  Legendary
# 0        49       49      False
# 1        62       63      False
# 2        82       83      False
# 3       100      123      False
# 4        52       43      False
# ..      ...      ...        ...
# 795     100      150       True
# 796     160      110       True
# 797     110       60       True
# 798     160       60       True
# 799     110      120       True
#
# [800 rows x 3 columns]

# %% [markdown]
# ## To read data from multiple files

# %%
from glob import glob

# %%
files = glob('data/stocks*.csv')
files
# Out:
# ['data\\stocks.csv',
#  'data\\stocks1.csv',
#  'data\\stocks2.csv',
#  'data\\stocks3.csv']

# %%
pd.concat( (pd.read_csv(file) for file in files),ignore_index=True)
# Out:
#           Date   Close    Volume Symbol
# 0   2016-10-03   31.50  14070500   CSCO
# 1   2016-10-03  112.52  21701800   AAPL
# 2   2016-10-03   57.42  19189500   MSFT
# 3   2016-10-04  113.00  29736800   AAPL
# 4   2016-10-04   57.24  20085900   MSFT
# 5   2016-10-04   31.35  18460400   CSCO
# 6   2016-10-05   57.64  16726400   MSFT
# 7   2016-10-05   31.59  11808600   CSCO
# 8   2016-10-05  113.05  21453100   AAPL
# 9   2016-10-03   31.50  14070500   CSCO
# 10  2016-10-03  112.52  21701800   AAPL
# 11  2016-10-03   57.42  19189500   MSFT
# 12  2016-10-04  113.00  29736800   AAPL
# 13  2016-10-04   57.24  20085900   MSFT
# 14  2016-10-04   31.35  18460400   CSCO
# 15  2016-10-05   57.64  16726400   MSFT
# 16  2016-10-05   31.59  11808600   CSCO
# 17  2016-10-05  113.05  21453100   AAPL
